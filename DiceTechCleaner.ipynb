# %%
import pandas as pd
import numpy as np
job_data_to_load = "dice_us_tech_original.csv"
job_data = pd.read_csv(job_data_to_load)

# %%
# drop unneeded columns
del job_data["advertiserurl"]
del job_data["jobid"]
del job_data["postdate"]
del job_data["shift"]
del job_data["uniq_id"]

# # split joblocation_address into city and state
new=job_data["joblocation_address"].str.split(",",n=1,expand=True)
job_data["Loc_state"]=new[1]
job_data["Loc_city"]=new[0]
del job_data["joblocation_address"]
# drop rows where required fields are empty
job_data = job_data.loc[job_data.Loc_state.notnull()]
job_data = job_data.loc[job_data.company.notnull()]
 
# Remove listings for Canadian states
job_data = job_data.loc[~job_data.Loc_state.str.contains("ON")]
job_data = job_data.loc[~job_data.Loc_state.str.contains("BC")]

# replace all links in site_name column with dice.com
job_data.loc[:,"site_name"] = "dice.com"
# add empty columns for Skills
job_data["Skills"] = np.nan
# rename columns to prep for merging with other datasets
job_data = job_data.rename(columns={"company":"Company","jobdescription":"Description","jobtitle":"Position",
                                    "employmenttype_jobstatus":"Type","site_name":"Source"})
# rearrange columns
job_data = job_data[["Position","Company","Description","Loc_state","Loc_city","Skills","Type","Source"]]
job_data.head(10)
# Out:
#                                             Position  \
# 0                           AUTOMATION TEST ENGINEER
# 1                      Information Security Engineer
# 2                       Business Solutions Architect
# 3  Java Developer (mid level)- FT- GREAT culture,...
# 4                                    DevOps Engineer
# 5                                 SAP FICO Architect
# 6                                   Network Engineer
# 7  Sr. Web Application Developer (Cloud Team) - C...
# 8                                Front End Developer
# 9                       Application Support Engineer
#
#                              Company  \
# 0  Digital Intelligence Systems, LLC
# 1  University of Chicago/IT Services
# 2               Galaxy Systems, Inc.
# 3                      TransTech LLC
# 4                   Matrix Resources
# 5                  Yash Technologies
# 6                             Noble1
# 7            Bluebeam Software, Inc.
# 8                          Genesis10
# 9    VanderHouwen & Associates, Inc.
#
#                                          Description Loc_state     Loc_city  \
# 0  Looking for Selenium engineers...must have sol...        GA      Atlanta
# 1  The University of Chicago has a rapidly growin...        IL      Chicago
# 2  GalaxE.SolutionsEvery day, our solutions affec...        IL   Schaumburg
# 3  Java DeveloperFull-time/direct-hireBolingbrook...        IL  Bolingbrook
# 4  Midtown based high tech firm has an immediate ...        GA      Atlanta
# 5  We are looking for a Senior SAP FICO Architect...        IL      Chicago
# 6  Network Engineer Job Description A Network Eng...        GA      Atlanta
# 7  Bluebeam is looking for talented sr. web devel...        IL      Chicago
# 8  This is a fulltime position for a Javascript d...        NY     New York
# 9  SummaryOur client is the leading provider of o...        WA      Seattle
#
#    Skills                                               Type    Source
# 0     NaN  C2H Corp-To-Corp, C2H Independent, C2H W2, 3 M...  dice.com
# 1     NaN                                          Full Time  dice.com
# 2     NaN                                          Full Time  dice.com
# 3     NaN                                          Full Time  dice.com
# 4     NaN                                          Full Time  dice.com
# 5     NaN                               Full Time, Permanant  dice.com
# 6     NaN                             Full Time, Direct Hire  dice.com
# 7     NaN                               Full Time, Full Time  dice.com
# 8     NaN                        Full Time, Direct Placement  dice.com
# 9     NaN                           C2H W2, Contract to hire  dice.com

# %%
job_data.count()
# Out:
# Position       21850
# Company        21850
# Description    21850
# Loc_state      21850
# Loc_city       21850
# Skills             0
# Type           21624
# Source         21850
# dtype: int64

# %%
Keywords = ["Data Scien", "Data Analy", "Data Eng", "Business Intelligence", "Tableau", "VBA", "Python", "JSON", "NumPy",  "Pandas", "Matplotlib", "Beautiful Soap", "Statistics Modeling", "API", "SQL", "MongoDB", "ETL", "HTML", "CSS", "JavaScript", "AJAX", "D3", "Leaflet", "Hadoop", "Machine Learning", "Product Analyst", "BI Analyst"]

filtered_job_data = job_data[job_data["Position"].str.contains("|".join(Keywords))]
filtered_job_data.to_csv("Dice_US_Tech_FilteredJobData.csv")
filtered_job_data.count()
# Out:
# Position       1566
# Company        1566
# Description    1566
# Loc_state      1566
# Loc_city       1566
# Skills            0
# Type           1556
# Source         1566
# dtype: int64
